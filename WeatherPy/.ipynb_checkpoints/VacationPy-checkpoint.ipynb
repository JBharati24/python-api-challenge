# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import holoviews as hv

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/city_data.csv")

# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 namdrik   5.5994  168.1028     28.82        74           9
# 1  hawaiian paradise park  19.5933 -154.9731     27.73        70          40
# 2                    tura  25.5198   90.2201     26.95        88           6
# 3                mil'kovo  55.6078   37.7956     15.27        72           4
# 4                 guaruja -23.9931  -46.2564     20.50        26           0
#
#    Wind Speed Country        Date
# 0        7.32      MH  1717979553
# 1        5.14      US  1717979553
# 2        1.62      IN  1717979553
# 3        2.10      RU  1717979553
# 4        2.00      BR  1717979553

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Create the map plot
city_map = city_data_df.hvplot.points(
    x='Lng', 
    y='Lat', 
    c='Humidity', 
    hover_cols=['City', 'Humidity'], 
    colorbar=True, 
    tiles='ESRI', 
    title='City Humidity', 
    xlabel='Longitude', 
    ylabel='Latitude', 
    frame_width=700, 
    frame_height=400, 
    geo=True
)

# Overlay the data along the 'Humidity' dimension
humidity_plots = []
for humidity, group in city_data_df.groupby('Humidity'):
    humidity_plot = group.hvplot.points(
        x='Lng', 
        y='Lat', 
        color='Humidity', 
        size='Humidity', 
        geo=True
    )
    humidity_plots.append(humidity_plot)

# Overlay all plots
city_map * hv.Overlay(humidity_plots)
# Display the map
city_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria
ideal_cities = city_data_df[
    (city_data_df["Max Temp"] < 29) &
    (city_data_df["Max Temp"] > 4) &
    (city_data_df["Wind Speed"] < 20) &
    (city_data_df["Cloudiness"] < 100)
]

# Drop any rows with null values
ideal_cities = ideal_cities.dropna()

# Display sample data
ideal_cities.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 namdrik   5.5994  168.1028     28.82        74           9
# 1  hawaiian paradise park  19.5933 -154.9731     27.73        70          40
# 2                    tura  25.5198   90.2201     26.95        88           6
# 3                mil'kovo  55.6078   37.7956     15.27        72           4
# 4                 guaruja -23.9931  -46.2564     20.50        26           0
#
#    Wind Speed Country        Date
# 0        7.32      MH  1717979553
# 1        5.14      US  1717979553
# 2        1.62      IN  1717979553
# 3        2.10      RU  1717979553
# 4        2.00      BR  1717979553

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#                      City Country      Lat       Lng  Humidity Hotel Name
# 0                 namdrik      MH   5.5994  168.1028        74
# 1  hawaiian paradise park      US  19.5933 -154.9731        70
# 2                    tura      IN  25.5198   90.2201        88
# 3                mil'kovo      RU  55.6078   37.7956        72
# 4                 guaruja      BR -23.9931  -46.2564        26

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# namdrik - nearest hotel: No hotel found
# hawaiian paradise park - nearest hotel: No hotel found
# tura - nearest hotel: Hotel Polo Orchid
# mil'kovo - nearest hotel: Дрозды
# guaruja - nearest hotel: Ferrareto Hotel
# rikaze - nearest hotel: Gesar Hotel
# ancud - nearest hotel: Cabañas
# blackmans bay - nearest hotel: Villa Howden
# ust-nera - nearest hotel: гостиница "Солнечная"
# invercargill - nearest hotel: The Grand
# carnarvon - nearest hotel: No hotel found
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# bilibino - nearest hotel: No hotel found
# kalabo - nearest hotel: Golden Lodge Luxury Acomodation
# qaqortoq - nearest hotel: Hotel Qaqortoq
# west island - nearest hotel: Cocos Village Bungalows
# ambovombe - nearest hotel: La source
# fauske - nearest hotel: Scandic Fauske
# sitka - nearest hotel: Aspen Suites Hotel
# remire-montjoly - nearest hotel: Complexe Belova
# yesilova - nearest hotel: Kural Apart
# taksimo - nearest hotel: No hotel found
# port elizabeth - nearest hotel: Waterford Hotel
# hasaki - nearest hotel: Choshi Plaza Hotel
# martapura - nearest hotel: Q-Hotel Grand Dafam
# natal - nearest hotel: Natal Palace Hotel
# udachny - nearest hotel: Вилюй
# stanley - nearest hotel: Hotel 52
# avarua - nearest hotel: Paradise Inn
# torghay - nearest hotel: No hotel found
# la ronge - nearest hotel: La Ronge Hotel and Suites
# mokhsogollokh - nearest hotel: No hotel found
# georgetown - nearest hotel: Page 63 hostel
# cabo san lucas - nearest hotel: Comfort Rooms
# yellowknife - nearest hotel: No hotel found
# brookings - nearest hotel: Quality Inn
# necochea - nearest hotel: Cabañas Río Quequén
# utrik - nearest hotel: No hotel found
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# palmer - nearest hotel: No hotel found
# bhachau - nearest hotel: No hotel found
# katsuren-haebaru - nearest hotel: No hotel found
# pionerskiy - nearest hotel: No hotel found
# alice springs - nearest hotel: Aurora Alice Springs
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# anadyr - nearest hotel: Гостевой дом
# khandyga - nearest hotel: Апельсин
# luganville - nearest hotel: Beachfront Resort
# bethel - nearest hotel: Hampton Inn Danbury
# tazovsky - nearest hotel: Тазовчанка
# hamilton - nearest hotel: North Vista Manor
# geraldton - nearest hotel: Ocean Centre Hotel
# damghan - nearest hotel: هتل جهانگردى دامغان
# port alfred - nearest hotel: No hotel found
# vilyuchinsk - nearest hotel: Победа
# calama - nearest hotel: Apart Hotel Geotel Calama
# coahuayana de hidalgo - nearest hotel: No hotel found
# albany - nearest hotel: No hotel found
# saint-philippe - nearest hotel: Le Baril
# alnashi - nearest hotel: No hotel found
# lompoc - nearest hotel: Red Roof Inn Lompoc
# aykhal - nearest hotel: Уют
# aleppo - nearest hotel: No hotel found
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# thompson - nearest hotel: Thompson Inn
# ribeira grande - nearest hotel: Hospedaria JSF
# concepcion del oro - nearest hotel: No hotel found
# acarau - nearest hotel: No hotel found
# enewetak - nearest hotel: No hotel found
# tsiombe - nearest hotel: No hotel found
# ciudad del maiz - nearest hotel: No hotel found
# touros - nearest hotel: Pousada Atlântico
# hermanus - nearest hotel: Aloe guest house
# camacupa - nearest hotel: No hotel found
# ormara - nearest hotel: No hotel found
# svobodnyy - nearest hotel: No hotel found
# pauini - nearest hotel: No hotel found
# yemetsk - nearest hotel: No hotel found
# zaysan - nearest hotel: Рахат қонақүй
# arkalyk - nearest hotel: Гостиница "Арсенал"
# tselinnoye - nearest hotel: Гостиница
# keflavik - nearest hotel: Núpan Deluxe
# sabha - nearest hotel: فندق الكاظم-سبها
# likasi - nearest hotel: Park Side
# qamdo - nearest hotel: 银杏商务宾馆
# leava - nearest hotel: Fia fia
# marsh harbour - nearest hotel: Lofty Fig Villas
# jeju city - nearest hotel: R&T 호텔
# alofi - nearest hotel: Matavai Resort
# hotan - nearest hotel: Hua Yi International Hotel (accepts foreigners)
# arraial do cabo - nearest hotel: No hotel found
# badger - nearest hotel: Clarion Hotel & Suites
# papatowai - nearest hotel: No hotel found
# daru - nearest hotel: Kuki
# januaria - nearest hotel: No hotel found
# varennes-vauzelles - nearest hotel: Campanile
# burshtyn - nearest hotel: Садиба мрій
# sen monorom - nearest hotel: Pich Tevy
# itamaraca - nearest hotel: No hotel found
# ceeldheer - nearest hotel: No hotel found
# diamantino - nearest hotel: Hotel kayaby
# baiti - nearest hotel: No hotel found
# kapuskasing - nearest hotel: Travelodge
# forster - nearest hotel: No hotel found
# coquimbo - nearest hotel: Hotel Iberia
# hadibu - nearest hotel: No hotel found
# ondjiva - nearest hotel: Combuesa
# campo gallo - nearest hotel: Hotel La Plaza
# port mathurin - nearest hotel: Escale Vacances
# amga - nearest hotel: "АммА"
# villiers - nearest hotel: No hotel found
# puerto colombia - nearest hotel: Hotel Puerto Colombia
# jindabyne - nearest hotel: Lake Jindabyne Hotel
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# cherepanovo - nearest hotel: Гостиница
# cidreira - nearest hotel: Hotel Castelo
# selfoss - nearest hotel: Miðgarður
# westport - nearest hotel: Norwalk Inn and Conference Center
# luena - nearest hotel: No hotel found
# noyabrsk - nearest hotel: Аляска
# hobyo - nearest hotel: Iftin Hotel Hobyo
# tolanaro - nearest hotel: Hôtel Mahavokey
# taiyuan - nearest hotel: 汾酒大厦
# suizhou - nearest hotel: Yan Emperor Hotel
# shiyan - nearest hotel: 汉庭酒店
# igarka - nearest hotel: Заполярье
# kangding - nearest hotel: 溜溜城格桑花大酒店
# lagos - nearest hotel: No hotel found
# bredasdorp - nearest hotel: Victoria Hotel
# tazacorte - nearest hotel: App Leyma
# pimentel - nearest hotel: Hospedaje Calle del Sol
# harstad - nearest hotel: Scandic Harstad
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# quezon - nearest hotel: No hotel found
# tamandare - nearest hotel: Pousada Baia dos Corais
# manta - nearest hotel: Hotel Santa Fe
# atafu village - nearest hotel: No hotel found
# nurabad - nearest hotel: No hotel found
# richards bay - nearest hotel: SUN1 Richards Bay
# kitimat - nearest hotel: MStar Hotel
# east london - nearest hotel: No hotel found
# launceston - nearest hotel: Hotel Charles
# gwanda - nearest hotel: No hotel found
# lebu - nearest hotel: No hotel found
# kabwe - nearest hotel: Tuskers Hotel
# khovd - nearest hotel: Khovd hotel
# queenstown - nearest hotel: Queens Hotel
# rivne - nearest hotel: Готель "ОК"
# vozdvizhenka - nearest hotel: No hotel found
# sao vicente - nearest hotel: Pousada Vitória
# cova figueira - nearest hotel: No hotel found
# new norfolk - nearest hotel: Woodbridge on the Derwent
# colonia - nearest hotel: Wasserturm Hotel Cologne
# greymouth - nearest hotel: Recreation Hotel
# namibe - nearest hotel: Nelsal Pensao
# trujillo - nearest hotel: Hostal Ayacucho
# portland - nearest hotel: the Hoxton
# louhans - nearest hotel: Le Chapon Bressan
# mitu - nearest hotel: Hotel Brasilia Vaupés
# briviesca - nearest hotel: Hotel Isabel
# charters towers - nearest hotel: No hotel found
# kusong - nearest hotel: No hotel found
# knysna - nearest hotel: Graywood Hotel
# broken hill - nearest hotel: Ibis Styles
# whitehorse - nearest hotel: Town & Mountain Hotel
# bodo - nearest hotel: Zefyr hotell
# trang - nearest hotel: No hotel found
# sittwe - nearest hotel: Yuzana Aung Motel 1
# dzerzhinskoye - nearest hotel: No hotel found
# n'zeto - nearest hotel: No hotel found
# kone - nearest hotel: Pacifik Appartels
# antonio enes - nearest hotel: Hotel Quirimbas
# ribas do rio pardo - nearest hotel: Hotel São Francisco
# yeppoon - nearest hotel: Blossom's on Seaspray
# west bay - nearest hotel: Bonnie's Arch
# reyes - nearest hotel: Hotel Santa Rosa
# zhangjiakou - nearest hotel: 商务宾馆
# oltinko'l - nearest hotel: No hotel found
# hauterive - nearest hotel: Auberge Bourbonnaise
# zabaykal'sk - nearest hotel: Гостиница Русь
# nadi - nearest hotel: President Hotel
# le port - nearest hotel: No hotel found
# uturoa - nearest hotel: Hawaiki Nui hotel
# carauari - nearest hotel: No hotel found
# shevchenko - nearest hotel: Premier Hotel Abri
# zarah sharan - nearest hotel: No hotel found
# masuguru - nearest hotel: No hotel found
# nouadhibou - nearest hotel: Hotel valencia
# sechura - nearest hotel: Maximus Inn
# den burg - nearest hotel: De Lindeboom
# itoman - nearest hotel: No hotel found
# belle fourche - nearest hotel: Kings Inn
# krasnokamensk - nearest hotel: Аргунь
# hithadhoo - nearest hotel: Pebbles Inn
# lensk - nearest hotel: No hotel found
# zeya - nearest hotel: Серебряный створ
# al qusayr - nearest hotel: No hotel found
# kailua-kona - nearest hotel: Kona Seaside Hotel
# labytnangi - nearest hotel: Семь лиственниц
# boguchany - nearest hotel: Полет
# leh - nearest hotel: Kang Lha Chen
# jefferson city - nearest hotel: DoubleTree by Hilton Jefferson City
# vila velha - nearest hotel: Hotel Prainha
# zhezqazghan - nearest hotel: No hotel found
# sokol - nearest hotel: Спецстрой
# hammerfest - nearest hotel: Thon Hotel Hammerfest
# laojunmiao - nearest hotel: No hotel found
# sandnessjoen - nearest hotel: Scandic Syv Søstre
# christchurch - nearest hotel: Ibis Hotel Christchurch
# mangai - nearest hotel: No hotel found
# xilin hot - nearest hotel: Hotel hailibu 120
# metlili chaamba - nearest hotel: No hotel found
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# manggar - nearest hotel: No hotel found
# sakaiminato - nearest hotel: かぐら旅館
# chernyshevskiy - nearest hotel: No hotel found
# magadi - nearest hotel: Udupi Upahara
# sheridan - nearest hotel: Comfort Inn & Suites
# mancio lima - nearest hotel: No hotel found
# gadzhiyevo - nearest hotel: Оазис
# egilsstadir - nearest hotel: Valaskjálf
# kununurra - nearest hotel: No hotel found
# letlhakane - nearest hotel: Boteti Hotel
# noosa heads - nearest hotel: Costa Nova Apartments
# salmas - nearest hotel: هتل آتا
# nabire - nearest hotel: Hotel Anggrek
# tehran - nearest hotel: هتل سعدی
# sinabang - nearest hotel: No hotel found
# san matias - nearest hotel: Hotel San Jose
# ocean city - nearest hotel: Watson's Regency Suites
# bubaque - nearest hotel: Chez Julio
# port shepstone - nearest hotel: The Spot Backpackers'
# itamarandiba - nearest hotel: No hotel found
# wake forest - nearest hotel: Sleep Inn
# freeport - nearest hotel: The Freeport Inn and Marina
# netrakona - nearest hotel: Shourov Hotel সৌরভ হোটেল
# leer - nearest hotel: Hotel Hafenspeicher
# karystos - nearest hotel: Galaxy Hotel
# kirensk - nearest hotel: Ивушка
# bastia - nearest hotel: Adonis Saint Florent
# bryne - nearest hotel: Jæren hotell
# broome - nearest hotel: No hotel found
# trincomalee - nearest hotel: Summer set inn
# duong dong - nearest hotel: Kim Hông Ngoc
# shelbyville - nearest hotel: No hotel found
# sitia - nearest hotel: Itanos Hotel
# ilhabela - nearest hotel: Vila Kebaya
# paranhos - nearest hotel: No hotel found
# east end - nearest hotel: No hotel found
# praia - nearest hotel: Casa Sodadi
# moshkovo - nearest hotel: Макушино
# okhotsk - nearest hotel: No hotel found
# holualoa - nearest hotel: Kona Hotel
# nikko - nearest hotel: ステーションホテル2番館
# mar del plata - nearest hotel: Gran hotel Mónaco
# sigli - nearest hotel: No hotel found
# labrador city - nearest hotel: Carol Inn
# nagqu - nearest hotel: Naqu Hotel
# dese - nearest hotel: Comfort Pension
# kalmunai - nearest hotel: Saji new food
# spearfish - nearest hotel: Best Western Black Hills Lodge
# thunder bay - nearest hotel: Hampton Inn & Suites by Hilton Thunder Bay
# kenora - nearest hotel: Travelodge
# choma - nearest hotel: No hotel found
# pachino - nearest hotel: Hotel Celeste
# lae - nearest hotel: Huon Gulf Hotel
# port-vila - nearest hotel: Holiday Inn Resort Vanuatu
# tefe - nearest hotel: Pousada Santa Teresa
# buulobarde - nearest hotel: No hotel found
# sao jose da coroa grande - nearest hotel: Hotel do Sol
# saint-jean-de-monts - nearest hotel: L'Espadon
# bindura - nearest hotel: Mayfair
# siluko - nearest hotel: No hotel found
# cacheu - nearest hotel: Delta Hotel
# smithers - nearest hotel: Sunshine Inn Hotel
# pelabuhanratu - nearest hotel: Hotel Augusta
# valdivia - nearest hotel: Esmeralda
# fisterra - nearest hotel: Hotel Temático do Banco Azul
# sartana - nearest hotel: Гранд Готель
# kunzelsau - nearest hotel: Zum Wilden Mann
# rengasdengklok - nearest hotel: No hotel found
# bad lausick - nearest hotel: Hotel Residenz - garni
# bom jesus - nearest hotel: Hotel Familiar
# macomb - nearest hotel: No hotel found
# at taj - nearest hotel: No hotel found
# turaif - nearest hotel: المودة
# visby - nearest hotel: Hotell Gute
# schuylkill haven - nearest hotel: Ramada
# sokoni - nearest hotel: No hotel found
# tailai - nearest hotel: No hotel found
# mangrol - nearest hotel: No hotel found
# lakatoro - nearest hotel: No hotel found
# ola - nearest hotel: No hotel found
# mogocha - nearest hotel: 7Ka
# taro - nearest hotel: Padma Resort Ubud
# ljusdal - nearest hotel: Stadshotell
# mount isa - nearest hotel: Ibis Styles
# conceicao do mato dentro - nearest hotel: Pires Pousada
# cristalina - nearest hotel: Goyás
# kerikeri - nearest hotel: Avalon Resort
# kismayo - nearest hotel: Kismayo Hotel
# yanam - nearest hotel: Hôtel Sarvainn
# uzgen - nearest hotel: Кунрат
# la rinconada - nearest hotel: Hotel Torre de los Guzmanes
# pundong - nearest hotel: Puri Ganjuran
# recani - nearest hotel: Hotel Merzouga
# lautoka - nearest hotel: Cathay Hotel
# misratah - nearest hotel: الفندق السياحى
# tibagi - nearest hotel: No hotel found
# richfield - nearest hotel: Sonesta Simply Suites Minneapolis Richfield
# tongouson - nearest hotel: No hotel found
# beipiao - nearest hotel: No hotel found
# aban - nearest hotel: No hotel found
# novodvinsk - nearest hotel: Уют
# ribeira brava - nearest hotel: Cheerfulway Bravamar Hotel
# ketchikan - nearest hotel: Cape Fox Lodge
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# horta - nearest hotel: Azoris Faial Garden - Resort Hotel
# longuyon - nearest hotel: Hôtel Restaurant Le Lutetia
# zarghun shahr - nearest hotel: No hotel found
# viedma - nearest hotel: Níjar
# san ramon - nearest hotel: Hyatt House
# koungheul - nearest hotel: Auberge Keur Ghan
# yulinshi - nearest hotel: 榆溪大酒店
# altai - nearest hotel: Altai hotel 40000-100000T
# sinop - nearest hotel: No hotel found
# san andres - nearest hotel: Hotel Decameron Isleño
#                        City Country      Lat       Lng  Humidity  \
# 0                   namdrik      MH   5.5994  168.1028        74
# 1    hawaiian paradise park      US  19.5933 -154.9731        70
# 2                      tura      IN  25.5198   90.2201        88
# 3                  mil'kovo      RU  55.6078   37.7956        72
# 4                   guaruja      BR -23.9931  -46.2564        26
# ..                      ...     ...      ...       ...       ...
# 544               koungheul      SN  13.9833  -14.8000        47
# 545                yulinshi      CN  38.2906  109.7494        30
# 547                   altai      MN  46.3722   96.2583        57
# 548                   sinop      TR  41.7711   34.8709        65
# 550              san andres      CO  12.5847  -81.7006        89
#
#                     Hotel Name
# 0               No hotel found
# 1               No hotel found
# 2            Hotel Polo Orchid
# 3                       Дрозды
# 4              Ferrareto Hotel
# ..                         ...
# 544          Auberge Keur Ghan
# 545                      榆溪大酒店
# 547  Altai hotel 40000-100000T
# 548             No hotel found
# 550     Hotel Decameron Isleño
#
# [327 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
# Configure the map plot
city_map2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 400,
    size = "Humidity",
    color="City",
    alpha=.75,
    hover_cols=["Hotel Name", "Country"]
)

# Display the map
city_map2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
